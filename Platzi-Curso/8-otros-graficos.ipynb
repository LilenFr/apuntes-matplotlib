# %% [markdown]
# ## Otros gráficos

# %%
# Importar
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.random.randint(1, 50, 100)

# %%
# Graficar Histograma
plt.hist(data)
plt.show()

# %%
# Alterar barras con bins
plt.hist(data, bins=50)
plt.show()

# %%
# Cambiar estilo
plt.hist(data, bins=10, histtype='step') 
plt.show()

# %%
# Graficar Boxplot
plt.boxplot(data)
plt.show()

# %%
# Graficar Scatter

N = 50
x = np.random.rand(N)
y = np.random.rand(N)
area = (30 * np.random.rand(N)) **2
colors = np.random.rand(N)

plt.scatter(x,y, s=area)
plt.show()

# %%
# Alterar gráfico anterior
plt.scatter(x, y, s=area, c=colors, marker='v')
plt.show()

# %%
# Agregar transparencia para ver los superpuestos
plt.scatter(x, y, s=area, c=colors, marker='o', alpha=0.5)
plt.show()
